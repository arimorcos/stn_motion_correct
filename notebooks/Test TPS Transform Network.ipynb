# %%
import sys
sys.path.append('..')

import numpy as np
import lasagne
import theano
import theano.tensor as T 
import networks

import os
import tiff_helpers
import image_manager
import datetime

# %matplotlib inline 
import matplotlib.pyplot as plt
plt.style.use('seaborn-paper')
# Out:
# Couldn't import dot_parser, loading of dot files will not be possible.
# Using gpu device 0: GeForce GTX TITAN X (CNMeM is disabled)

# %%
batch_size = 16

# %%
# Create image handler
im_handler = image_manager.image_manager(batch_size=batch_size)

# Advance schedule for the first time 
im_handler.advance_schedule()

# %%
# Create network 
reload(networks)
network = networks.stn_tps(batch_size=batch_size, save_every=100000)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-44-a7c8071c1b7b> in <module>()
#       1 # Create network
#       2 reload(networks)
# ----> 3 network = networks.stn_tps(batch_size=batch_size, save_every=100000)
#
# /home/arimorcos/Github/stn_motion_correct/networks.py in __init__(self, batch_size, alpha, max_norm, log_dir, save_every, dropout_frac, initialization, num_control_points)
#     549         # Initialize the process and cost functions
#     550         self.initialize_get_tps_params()
# --> 551         self.initialize_cost()
#     552
#     553         # Initialize adam
#
# /home/arimorcos/Github/stn_motion_correct/networks.py in initialize_cost(self)
#     555
#     556     def initialize_cost(self):
# --> 557         self.cost = self.get_cost(self.input_batch, self.ref_imgs)
#     558
#     559     def get_cost(self, input_batch, ref_imgs):
#
# /home/arimorcos/Github/stn_motion_correct/networks.py in get_cost(self, input_batch, ref_imgs)
#     566
#     567         # Get tps parameters
# --> 568         tps_params = self.get_tps_params(input_batch)
#     569
#     570         # apply transform
#
# /usr/local/lib/python2.7/dist-packages/theano/compile/function_module.pyc in __call__(self, *args, **kwargs)
#     784                         s.storage[0] = s.type.filter(
#     785                             arg, strict=s.strict,
# --> 786                             allow_downcast=s.allow_downcast)
#     787
#     788                     except Exception as e:
#
# /usr/local/lib/python2.7/dist-packages/theano/tensor/type.pyc in filter(self, data, strict, allow_downcast)
#      84         if isinstance(data, Variable):
#      85             raise TypeError(
# ---> 86                 'Expected an array-like object, but found a Variable: '
#      87                 'maybe you are trying to call a function on a (possibly '
#      88                 'shared) variable instead of a numeric array?')
#
# TypeError: ('Bad input argument to theano function with name "../networks.py:618"  at index 0(0-based)', 'Expected an array-like object, but found a Variable: maybe you are trying to call a function on a (possibly shared) variable instead of a numeric array?')

# %%
curr_batch_input, curr_batch_ref = im_handler.offer_data()

# %%
ind = 0

# %%
curr_batch_input, curr_batch_ref = im_handler.offer_data()
fig = plt.figure(figsize=(10,5))
ax = fig.add_subplot(121)
ax.imshow(curr_batch_input[ind, 0, :, :], cmap='gray');
ax = fig.add_subplot(122)
ax.imshow(temp[ind, :, :], cmap='gray');
ind += 1

# %%
root_dir = '/media/arimorcos/4TB External/stn_conv_net'
new_log_dir = os.path.join(root_dir, datetime.datetime.now().strftime('%y%m%d_%H%M%S'))
network.set_log_dir(new_log_dir)

# %%
curr_batch_input, curr_batch_ref = im_handler.offer_data()
test_input = np.transpose(np.expand_dims(curr_batch_ref, axis=3), axes=(0, 3, 1, 2))
test_input = np.tile(test_input, (1, 2, 1, 1))
network.get_cost(test_input, curr_batch_ref)

# %%
curr_batch_input, curr_batch_ref = im_handler.offer_data()

# %%
temp_cost = network.train_adam_helper(curr_batch_input, curr_batch_ref)
temp_cost

# %%
fig = plt.figure(figsize=(10,5))
ax = fig.add_subplot(121)
ax.imshow(test_out[ind, :, :], cmap='gray');
ax = fig.add_subplot(122)
ax.imshow(curr_batch_ref[ind, :, :], cmap='gray');
ind += 1

# %%
test_out = network.process(curr_batch_input)

# %%
test_out = curr_batch_input[:, 0, :, :]
diff = test_out - curr_batch_ref
(diff**2).mean()
